# %% [markdown]
# # Workgroup 3
# ### Integrantes:
# - Diego Esteban Quispe (20192073)
# - Yoberon
# - Teresa Sangay (20175906)

# %% [markdown]
# ### Exploring a DataFrame

# %%
#!pip install openpyxl
import numpy as np
import pandas as pd
from pandas import DataFrame,Series

# %%
#Importamos la base de datos
junin = pd.read_excel(r'../../data/Region_Junin.xlsx')

# %%
junin.head()
# Out:
#    Unnamed: 0 Region          District               Place  4_6_years_men  \
# 0           0  JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 1           1  JUNIN  CIUDAD DEL CERRO        P.YANACANCHA              1
# 2           2  JUNIN  CIUDAD DEL CERRO                VICO              1
# 3           3  JUNIN  CIUDAD DEL CERRO               RANCA              0
# 4           4  JUNIN  CIUDAD DEL CERRO               PASCO              4
#
#    4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 0               46              111             297               171
# 1                3                4              49                47
# 2                0                1              46                25
# 3                6                6              25                19
# 4                4                8              21                21
#
#    6_14_years_total  ...  not_finished_instr_women  not_finished_instr_total  \
# 0               468  ...                       209                       544
# 1                96  ...                        50                       100
# 2                71  ...                        25                        72
# 3                44  ...                        25                        50
# 4                42  ...                        25                        50
#
#    peruvian_men  peruvian_women  foreign_men  foreign_women  whites  natives  \
# 0           361             216            1              1       4      284
# 1            50              50            0              0       0      100
# 2            47              25            0              0       0       69
# 3            25              25            0              0       0       25
# 4            25              25            0              0       0       37
#
#    mestizos  blacks
# 0       290       1
# 1         0       0
# 2         3       0
# 3        25       0
# 4        13       0
#
# [5 rows x 42 columns]

# %% [markdown]
# #### 1. Obtener el nombre de todas las variables

# %%
#Nombre de todas las variables
print(junin.columns)
# Out:
# Index(['Unnamed: 0', 'Region', 'District', 'Place', '4_6_years_men',
#        '4_6_years_women', '4_6_years_total', '6_14_years_men',
#        '6_14_years_women', '6_14_years_total', 'man_read', 'women_read',
#        'total_read', 'men_not_read', 'women_not_read', 'total_not_read',
#        'man_write', 'women_write', 'total_write', 'men_not_write',
#        'women_not_write', 'total_not_write', 'instruction_men',
#        'instruction_women', 'instruction_total', 'no_instruction_men',
#        'no_instruction_women', 'no_instruction_total', 'finished_instr_men',
#        'finished_instr_women', 'finished_instr_total',
#        'not_finished_instr_men', 'not_finished_instr_women',
#        'not_finished_instr_total', 'peruvian_men', 'peruvian_women',
#        'foreign_men', 'foreign_women', 'whites', 'natives', 'mestizos',
#        'blacks'],
#       dtype='object')

# %% [markdown]
# #### 2. Mostrar el tipo de variables (type) así como presentar los principales estadísticos.

# %%
#Tipo de variables
junin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                197 non-null    int64
#  1   Region                    197 non-null    object
#  2   District                  197 non-null    object
#  3   Place                     197 non-null    object
#  4   4_6_years_men             197 non-null    int64
#  5   4_6_years_women           197 non-null    int64
#  6   4_6_years_total           197 non-null    int64
#  7   6_14_years_men            197 non-null    int64
#  8   6_14_years_women          197 non-null    int64
#  9   6_14_years_total          197 non-null    int64
#  10  man_read                  197 non-null    int64
#  11  women_read                197 non-null    int64
#  12  total_read                197 non-null    int64
#  13  men_not_read              197 non-null    int64
#  14  women_not_read            197 non-null    int64
#  15  total_not_read            197 non-null    int64
#  16  man_write                 197 non-null    int64
#  17  women_write               197 non-null    int64
#  18  total_write               197 non-null    int64
#  19  men_not_write             197 non-null    int64
#  20  women_not_write           197 non-null    int64
#  21  total_not_write           197 non-null    int64
#  22  instruction_men           197 non-null    int64
#  23  instruction_women         197 non-null    int64
#  24  instruction_total         197 non-null    int64
#  25  no_instruction_men        197 non-null    int64
#  26  no_instruction_women      197 non-null    int64
#  27  no_instruction_total      197 non-null    int64
#  28  finished_instr_men        197 non-null    int64
#  29  finished_instr_women      197 non-null    int64
#  30  finished_instr_total      197 non-null    int64
#  31  not_finished_instr_men    197 non-null    int64
#  32  not_finished_instr_women  197 non-null    int64
#  33  not_finished_instr_total  197 non-null    int64
#  34  peruvian_men              197 non-null    int64
#  35  peruvian_women            197 non-null    int64
#  36  foreign_men               197 non-null    int64
#  37  foreign_women             197 non-null    int64
#  38  whites                    197 non-null    int64
#  39  natives                   197 non-null    int64
#  40  mestizos                  197 non-null    int64
#  41  blacks                    197 non-null    int64
# dtypes: int64(39), object(3)
# memory usage: 64.8+ KB

# %%
#Estadisticas descriptivas de todas las variables
junin.describe()
# Out:
#        Unnamed: 0  4_6_years_men  4_6_years_women  4_6_years_total  \
# count  197.000000     197.000000       197.000000       197.000000
# mean    98.000000      16.979695        15.345178        32.324873
# std     57.013156      22.571419        21.618979        43.489455
# min      0.000000       0.000000         0.000000         0.000000
# 25%     49.000000       4.000000         4.000000         8.000000
# 50%     98.000000      10.000000         9.000000        20.000000
# 75%    147.000000      20.000000        18.000000        39.000000
# max    196.000000     184.000000       184.000000       368.000000
#
#        6_14_years_men  6_14_years_women  6_14_years_total    man_read  \
# count      197.000000        197.000000        197.000000  197.000000
# mean        79.005076         62.482234        141.538071   34.654822
# std         99.837291         90.879972        188.535210   51.091581
# min          0.000000          0.000000         10.000000    0.000000
# 25%         25.000000         19.000000         42.000000    2.000000
# 50%         55.000000         41.000000         91.000000   21.000000
# 75%         88.000000         73.000000        160.000000   42.000000
# max        950.000000        957.000000       1907.000000  317.000000
#
#        women_read  total_read  ...  not_finished_instr_women  \
# count  197.000000  197.000000  ...                197.000000
# mean    11.705584   46.360406  ...                 79.238579
# std     34.676708   83.291516  ...                111.799104
# min      0.000000    0.000000  ...                  0.000000
# 25%      0.000000    2.000000  ...                 25.000000
# 50%      0.000000   23.000000  ...                 50.000000
# 75%      7.000000   50.000000  ...                 94.000000
# max    225.000000  542.000000  ...               1089.000000
#
#        not_finished_instr_total  peruvian_men  peruvian_women  foreign_men  \
# count                197.000000    197.000000      197.000000   197.000000
# mean                 172.675127     95.918782       77.664975     0.030457
# std                  220.657751    120.177520      110.539722     0.265511
# min                    0.000000      0.000000        0.000000     0.000000
# 25%                   50.000000     31.000000       25.000000     0.000000
# 50%                  108.000000     65.000000       50.000000     0.000000
# 75%                  197.000000    103.000000       91.000000     0.000000
# max                 2164.000000   1132.000000     1141.000000     3.000000
#
#        foreign_women      whites      natives    mestizos      blacks
# count     197.000000  197.000000   197.000000  197.000000  197.000000
# mean        0.010152    9.893401   110.558376   52.583756    0.776650
# std         0.100501   39.677190   131.094774  123.120065    7.584952
# min         0.000000    0.000000     0.000000    0.000000    0.000000
# 25%         0.000000    0.000000    40.000000    0.000000    0.000000
# 50%         0.000000    0.000000    73.000000    3.000000    0.000000
# 75%         0.000000    0.000000   143.000000   48.000000    0.000000
# max         1.000000  348.000000  1367.000000  808.000000   92.000000
#
# [8 rows x 39 columns]

# %% [markdown]
# #### 3. Verifique si las columnas presentan missing values

# %%
np.any(junin.iloc[:,1].isnull())
# Out:
# False

# %%
#Codigo para encontrar variables con missing values
for i in np.arange(1,len(junin.columns)):
    if np.any(junin.iloc[:,i].isnull()):
        print(junin.columns[i])

# %% [markdown]
# Como el anterior bloque no tiene algun output, podemos decir que todas las variables no tienen missing values.

# %% [markdown]
# #### 4. Cambie el nombre de las variables
# - men_not_read: nlee_hombre
# - women_not_read: nlee_mujer
# - total_not_read: ntotal_lee
# - men_not_write: nesc_hombre
# - women_not_write: nesc_mujer
# - total_not_write: nesc_total

# %%
#Cambiando nombres de variables
junin.rename(columns = {'men_not_read':'nlee_hombre', 'women_not_read':'nlee_mujer',
                        'total_not_read':'ntotal_lee', 'men_not_write':'nesc_hombre',
                        'women_not_write':'nesc_mujer', 'total_not_write':'nesc_total',
                        'Place':'comunidad'}, inplace = True)

# %%
junin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                197 non-null    int64
#  1   Region                    197 non-null    object
#  2   District                  197 non-null    object
#  3   comunidad                 197 non-null    object
#  4   4_6_years_men             197 non-null    int64
#  5   4_6_years_women           197 non-null    int64
#  6   4_6_years_total           197 non-null    int64
#  7   6_14_years_men            197 non-null    int64
#  8   6_14_years_women          197 non-null    int64
#  9   6_14_years_total          197 non-null    int64
#  10  man_read                  197 non-null    int64
#  11  women_read                197 non-null    int64
#  12  total_read                197 non-null    int64
#  13  nlee_hombre               197 non-null    int64
#  14  nlee_mujer                197 non-null    int64
#  15  ntotal_lee                197 non-null    int64
#  16  man_write                 197 non-null    int64
#  17  women_write               197 non-null    int64
#  18  total_write               197 non-null    int64
#  19  nesc_hombre               197 non-null    int64
#  20  nesc_mujer                197 non-null    int64
#  21  nesc_total                197 non-null    int64
#  22  instruction_men           197 non-null    int64
#  23  instruction_women         197 non-null    int64
#  24  instruction_total         197 non-null    int64
#  25  no_instruction_men        197 non-null    int64
#  26  no_instruction_women      197 non-null    int64
#  27  no_instruction_total      197 non-null    int64
#  28  finished_instr_men        197 non-null    int64
#  29  finished_instr_women      197 non-null    int64
#  30  finished_instr_total      197 non-null    int64
#  31  not_finished_instr_men    197 non-null    int64
#  32  not_finished_instr_women  197 non-null    int64
#  33  not_finished_instr_total  197 non-null    int64
#  34  peruvian_men              197 non-null    int64
#  35  peruvian_women            197 non-null    int64
#  36  foreign_men               197 non-null    int64
#  37  foreign_women             197 non-null    int64
#  38  whites                    197 non-null    int64
#  39  natives                   197 non-null    int64
#  40  mestizos                  197 non-null    int64
#  41  blacks                    197 non-null    int64
# dtypes: int64(39), object(3)
# memory usage: 64.8+ KB

# %% [markdown]
# #### 6. Muestre los valores únicos de las siguientes variables ( comunidad , District)

# %%
import pandas as pd #importamos libreria

print(junin['comunidad'].unique(),"\n")
print(junin['District'].unique())
# Out:
# ['C.CIUDAD DEL CERRO' 'P.YANACANCHA' 'VICO' 'RANCA' 'PASCO' 'QUIRLACOCHA'
#  'CAJAMARQUILLA' 'CAICO' 'ROCO' 'C.SACRA FAMILIA' 'P.QUINUA'
#  'H.PARIAHUANCA' 'P.SULLUMARCA' 'H.SAN ANDRÉS' 'P.HUALLAY' 'C.HUAYCHAO'
#  'COCHAMARCA' 'P.CHACAYÁN' 'VILCABAMBA' 'CUCHES' 'CHANGO' 'MITO'
#  'ANTAPIRCA' 'P.CAYNA' 'A. COLPAS' 'P.YACAS' 'C.MASQUIN' 'P.YAMOR'
#  'PÁUCAR' 'TANGOR' 'QUIO' 'CAURY' 'CHUCCHUC' 'COQUIN' 'A.YAPOC'
#  'P.YANAHUANCA' 'HUAYLACIRCA' 'HUARANTAMBO' 'ANDUCHACA' 'VILLO'
#  'MICHIVILCA' 'PILLAO' 'YACÁN' 'TÁPUC' 'CHAUPIMARCA' 'P.OXAPAMPA'
#  'P.JAUJA' 'A.CHUNÁN' 'C.PACAPACHA' 'HUANCAS' 'A.HUERTAS' 'PACA' 'MASMA'
#  'ATAURA' 'HUALÁ' 'JULCÁN' 'P.RICRÁN' 'A.PAUCÁN' 'P.APATA' 'HUAMALÍ'
#  'A.SAN LORENZO' 'PACUCHO' 'P.ORCOTUNA' 'A.VICSO' 'TISTES' 'P.HUARIPAMPA'
#  'A.PARCO' 'PACCHA' 'CANCHAPUNCO' 'C.ULLUSCA' 'CANCHAS' 'P.MUQUIYAUYO'
#  'MUQUI' 'P.ACOLLA' 'MARCO' 'TRAGADERO' 'CHOCÓN' 'ACAYA' 'YAUJAILLO'
#  'CURICACA' 'P.CINCOS' 'C.LLACUARI' 'P.HUANCARÍ' 'C.CHALHUAS' 'ARAMACHAY'
#  'P.MITO' 'A.CHAMBARÁ' 'C.QUICHA' 'HUACHAC' 'A.ACO' 'P.LLOCLLAPAMPA'
#  'VISCAS ESPERANZA' 'CONCHAILLO' 'MATA-CHICO' 'MATA-GRANDE' 'P.CONCEPCIÓN'
#  'SANTA ROSA DE OCOPA' 'HUANTAR' 'A.ALAYO' 'C.SAN ANTONIO DE CARICANCHO'
#  'SANTO DOMINGO' 'P.CÓMAS' 'C.CHUPA' 'COCHAS' 'P.MATAHUASI' 'P.HUANCAYO'
#  'CAJAS' 'P.CHUPACA' 'A.ISCOS' 'ANTAPAMPA' 'HUAUSCA GRANDE'
#  'SAN JUAN DE TARPA' 'YANACANCHA' 'COPCA' 'HUAYAN' 'HUAMANCACA'
#  'PILCOMAYO' 'AHUAC' 'ACAC' 'P.SAN GERÓNIMO' 'HUALHUAS'
#  'SAN PEDRO DE SAÑO' 'QUICHUAY' 'CASACANCHA' 'A.INGENIO'
#  'P.SANTA CRUZ DE QUILCAY' 'RANGRA' 'P.SAPALLANGA' 'A.LA PUNTA' 'P.PUCARÁ'
#  'C.PATALÁ' 'MARCAVALLE' 'COCHARCAS' 'P.CHONGOS' 'C.TURPAC Y TINYARI'
#  'SOCOS' 'PUMPUNGA' 'CHUPURO' 'CARHUAPACHA' 'A.HUAMANCACA' 'P.SICAYA'
#  'A.HUANCHAC' 'C.CACHICAMARCA' 'P.COLCA' 'A.CHACAPAMPA' 'HUASICANCHA'
#  'CUCHO' 'CHILIAY' 'POTACA' 'LARIA' 'CHONGOS ALTO' 'P.HUAYUCACHI'
#  'HUAMANMARCA' 'VIQUES' 'CACAS' 'HUARAPUQUIO' 'CULLHUAS' 'RETAMA' 'PACHA'
#  'P.TARMA' 'MACO' 'MULLUERO' 'ANDAMARCA' 'CHANCHA' 'TARMATAMBO' 'P.JUNÍN'
#  'HUASAHUASY' 'PARI' 'YANEC' 'CHUPÁN' 'ACONCOCHA' 'ONDORES' 'P.ACOBAMBA'
#  'PICOY' 'C.HUARACAYO' 'A.PALCA' 'C.HUAILAHUICHÁN' 'P.PALCAMAYO' 'P.OROYA'
#  'HUAYNACANCHA' 'HUAYHUAY' 'P.CARHUAMAYO' 'ULCUMAYO' 'P.SAN RAMÓN'
#  'LA MERCED' 'P.VISCATÁN' 'PAN DE AZÚCAR' 'SUITUCANCHA' 'CHACAPALCA'
#  'P.POMACOCHA' 'PACHACHACA' 'YAULI' 'MINAS DE MOROCOCHA']
#
# ['CIUDAD DEL CERRO' 'HUAYLLAY' 'CHACAYÁN' 'CAYNA' 'YANAHUANCA' 'NINACACA'
#  'JAUJA' 'APATA' 'ORCOTUNA' 'HUARIPAMPA' 'MUQUIYAUYO' 'ACOLLA' 'CINCOS'
#  'MITO' 'LLOCLLAPAMPA' 'CONCEPCIÓN' 'COCHAS' 'MATAHUASI' 'HUANCAYO'
#  'CHUPACA' 'SAN GERÓNIMO' 'SAPALLANGA' 'CHONGOS' 'SICAYA' 'COLCA'
#  'HUAYUCACHI' 'TARMA' 'JUNÍN' 'ACOBAMBA' 'OROYA' 'CARHUAMAYO'
#  'CHANCHAMAYO' 'VITOC' 'CHACAPALCA' 'YAULI']

# %% [markdown]
# #### 7. Borrar las varaibles finished_instr_total, finished_instr_men y finished_instr_women

# %%
junin_2 = junin.drop(['finished_instr_total','finished_instr_men', 'finished_instr_women'],  axis = 1)
junin_2 #renombramos la  base sin las columnas elimnadas
# Out:
#      Unnamed: 0 Region          District           comunidad  4_6_years_men  \
# 0             0  JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 1             1  JUNIN  CIUDAD DEL CERRO        P.YANACANCHA              1
# 2             2  JUNIN  CIUDAD DEL CERRO                VICO              1
# 3             3  JUNIN  CIUDAD DEL CERRO               RANCA              0
# 4             4  JUNIN  CIUDAD DEL CERRO               PASCO              4
# ..          ...    ...               ...                 ...            ...
# 192         192  JUNIN        CHACAPALCA          CHACAPALCA              1
# 193         193  JUNIN             YAULI         P.POMACOCHA              1
# 194         194  JUNIN             YAULI          PACHACHACA              2
# 195         195  JUNIN             YAULI               YAULI              2
# 196         196  JUNIN             YAULI  MINAS DE MOROCOCHA              9
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 0                 46              111             297               171
# 1                  3                4              49                47
# 2                  0                1              46                25
# 3                  6                6              25                19
# 4                  4                8              21                21
# ..               ...              ...             ...               ...
# 192                0                1              71                 0
# 193                0                1              15                 7
# 194                0                2              20                 8
# 195                6                8              74                38
# 196                5               14              87                25
#
#      6_14_years_total  ...  not_finished_instr_women  \
# 0                 468  ...                       209
# 1                  96  ...                        50
# 2                  71  ...                        25
# 3                  44  ...                        25
# 4                  42  ...                        25
# ..                ...  ...                       ...
# 192                71  ...                         0
# 193                22  ...                         7
# 194                28  ...                         8
# 195               112  ...                        37
# 196               112  ...                        30
#
#      not_finished_instr_total  peruvian_men  peruvian_women  foreign_men  \
# 0                         544           361             216            1
# 1                         100            50              50            0
# 2                          72            47              25            0
# 3                          50            25              25            0
# 4                          50            25              25            0
# ..                        ...           ...             ...          ...
# 192                        72            72               0            0
# 193                        23            16               7            0
# 194                        30            22               8            0
# 195                       103            76              44            0
# 196                       126            96              30            0
#
#      foreign_women  whites  natives  mestizos  blacks
# 0                1       4      284       290       1
# 1                0       0      100         0       0
# 2                0       0       69         3       0
# 3                0       0       25        25       0
# 4                0       0       37        13       0
# ..             ...     ...      ...       ...     ...
# 192              0       0       35        39       0
# 193              0       0       21         2       0
# 194              0       0        4        26       0
# 195              0      37       14        69       0
# 196              0       1      118         7       0
#
# [197 rows x 39 columns]

# %% [markdown]
# #### 8. Crear columnas con las siguiente información: el % de mujeres que no escriben ni leen, % de varones que no escriben ni leen y % de nativos respecto al total de la población.

# %%
junin_2['Total_Poblacion']=(junin_2['whites']+junin_2['natives']+junin_2['mestizos']+junin_2['blacks']) #total de la población


junin_2['mujeres_nwrite'] = (((junin_2['nlee_mujer'])/junin_2['Total_Poblacion'])*100).round() #% de mujeres que no escriben
junin_2['mujeres_nread'] = (((junin_2['nlee_mujer'])/junin_2['Total_Poblacion'])*100).round() #% de mujeres que no escribe
junin_2['hombres_nwrite'] =(((junin_2['nlee_hombre'])/junin_2['Total_Poblacion'])*100).round()
junin_2['hombres_nread'] =(((junin_2['nlee_hombre'])/junin_2['Total_Poblacion'])*100).round()
junin_2['percent_nativos'] =(((junin_2['natives'])/junin_2['Total_Poblacion'])*100).round()

junin_2
# Out:
#      Unnamed: 0 Region          District           comunidad  4_6_years_men  \
# 0             0  JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 1             1  JUNIN  CIUDAD DEL CERRO        P.YANACANCHA              1
# 2             2  JUNIN  CIUDAD DEL CERRO                VICO              1
# 3             3  JUNIN  CIUDAD DEL CERRO               RANCA              0
# 4             4  JUNIN  CIUDAD DEL CERRO               PASCO              4
# ..          ...    ...               ...                 ...            ...
# 192         192  JUNIN        CHACAPALCA          CHACAPALCA              1
# 193         193  JUNIN             YAULI         P.POMACOCHA              1
# 194         194  JUNIN             YAULI          PACHACHACA              2
# 195         195  JUNIN             YAULI               YAULI              2
# 196         196  JUNIN             YAULI  MINAS DE MOROCOCHA              9
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 0                 46              111             297               171
# 1                  3                4              49                47
# 2                  0                1              46                25
# 3                  6                6              25                19
# 4                  4                8              21                21
# ..               ...              ...             ...               ...
# 192                0                1              71                 0
# 193                0                1              15                 7
# 194                0                2              20                 8
# 195                6                8              74                38
# 196                5               14              87                25
#
#      6_14_years_total  ...  whites  natives  mestizos  blacks  \
# 0                 468  ...       4      284       290       1
# 1                  96  ...       0      100         0       0
# 2                  71  ...       0       69         3       0
# 3                  44  ...       0       25        25       0
# 4                  42  ...       0       37        13       0
# ..                ...  ...     ...      ...       ...     ...
# 192                71  ...       0       35        39       0
# 193                22  ...       0       21         2       0
# 194                28  ...       0        4        26       0
# 195               112  ...      37       14        69       0
# 196               112  ...       1      118         7       0
#
#      Total_Poblacion  mujeres_nwrite  mujeres_nread  hombres_nwrite  \
# 0                579            25.0           25.0            35.0
# 1                100            50.0           50.0            20.0
# 2                 72            35.0           35.0            31.0
# 3                 50            50.0           50.0             0.0
# 4                 50            50.0           50.0            44.0
# ..               ...             ...            ...             ...
# 192               74             0.0            0.0            41.0
# 193               23            30.0           30.0            35.0
# 194               30            23.0           23.0            50.0
# 195              120            18.0           18.0            29.0
# 196              126            24.0           24.0            70.0
#
#      hombres_nread  percent_nativos
# 0             35.0             49.0
# 1             20.0            100.0
# 2             31.0             96.0
# 3              0.0             50.0
# 4             44.0             74.0
# ..             ...              ...
# 192           41.0             47.0
# 193           35.0             91.0
# 194           50.0             13.0
# 195           29.0             12.0
# 196           70.0             94.0
#
# [197 rows x 45 columns]

# %% [markdown]
# #### 9. Crear una base de datos con la siguiente información:
# - Quedarse con la información de los distritos de Ciudad del Cerro, Jauja, Acolla, San Gerónimo, Tarma, Oroya y Concepción
# - Ciudades con una cantidad de niños (4-6 años) mayor a 50 y de (6-14 años) > 70
# - Ordenar las variables según el total de la población y cantidad de población nativa
# - Solo quedarse con las variables trabajadas en 8, Distrito, y comunidad.
# - Guardar la mitad de la información en bases diferentes (llamar a cada uno Base1 y Base 2)
# - Guardar la Base1 en formato csv y excel en la carpeta data. (Use el siguiente nombre Base1_WG(numero de grupo))

# %%
# extraer las filas con la información de los districtos requeridos

districts = junin_2[(junin_2['District'].isin(['CIUDAD DEL CERRO','JAUJA','ACOLLA','SAN GERÓNIMO','TARMA','OROYA','CONCEPCIÓN']))]

districts
# Out:
#      Unnamed: 0 Region          District                    comunidad  \
# 0             0  JUNIN  CIUDAD DEL CERRO           C.CIUDAD DEL CERRO
# 1             1  JUNIN  CIUDAD DEL CERRO                 P.YANACANCHA
# 2             2  JUNIN  CIUDAD DEL CERRO                         VICO
# 3             3  JUNIN  CIUDAD DEL CERRO                        RANCA
# 4             4  JUNIN  CIUDAD DEL CERRO                        PASCO
# 5             5  JUNIN  CIUDAD DEL CERRO                  QUIRLACOCHA
# 6             6  JUNIN  CIUDAD DEL CERRO                CAJAMARQUILLA
# 7             7  JUNIN  CIUDAD DEL CERRO                        CAICO
# 8             8  JUNIN  CIUDAD DEL CERRO                         ROCO
# 9             9  JUNIN  CIUDAD DEL CERRO              C.SACRA FAMILIA
# 10           10  JUNIN  CIUDAD DEL CERRO                     P.QUINUA
# 11           11  JUNIN  CIUDAD DEL CERRO                H.PARIAHUANCA
# 12           12  JUNIN  CIUDAD DEL CERRO                 P.SULLUMARCA
# 13           13  JUNIN  CIUDAD DEL CERRO                 H.SAN ANDRÉS
# 47           47  JUNIN             JAUJA                      P.JAUJA
# 48           48  JUNIN             JAUJA                     A.CHUNÁN
# 49           49  JUNIN             JAUJA                  C.PACAPACHA
# 50           50  JUNIN             JAUJA                      HUANCAS
# 51           51  JUNIN             JAUJA                    A.HUERTAS
# 52           52  JUNIN             JAUJA                         PACA
# 53           53  JUNIN             JAUJA                        MASMA
# 54           54  JUNIN             JAUJA                       ATAURA
# 55           55  JUNIN             JAUJA                        HUALÁ
# 56           56  JUNIN             JAUJA                       JULCÁN
# 57           57  JUNIN             JAUJA                     P.RICRÁN
# 58           58  JUNIN             JAUJA                     A.PAUCÁN
# 74           74  JUNIN            ACOLLA                     P.ACOLLA
# 75           75  JUNIN            ACOLLA                        MARCO
# 76           76  JUNIN            ACOLLA                    TRAGADERO
# 77           77  JUNIN            ACOLLA                       CHOCÓN
# 78           78  JUNIN            ACOLLA                        ACAYA
# 79           79  JUNIN            ACOLLA                    YAUJAILLO
# 80           80  JUNIN            ACOLLA                     CURICACA
# 96           96  JUNIN        CONCEPCIÓN                 P.CONCEPCIÓN
# 97           97  JUNIN        CONCEPCIÓN          SANTA ROSA DE OCOPA
# 98           98  JUNIN        CONCEPCIÓN                      HUANTAR
# 99           99  JUNIN        CONCEPCIÓN                      A.ALAYO
# 100         100  JUNIN        CONCEPCIÓN  C.SAN ANTONIO DE CARICANCHO
# 101         101  JUNIN        CONCEPCIÓN                SANTO DOMINGO
# 121         121  JUNIN      SAN GERÓNIMO               P.SAN GERÓNIMO
# 122         122  JUNIN      SAN GERÓNIMO                     HUALHUAS
# 123         123  JUNIN      SAN GERÓNIMO            SAN PEDRO DE SAÑO
# 124         124  JUNIN      SAN GERÓNIMO                     QUICHUAY
# 125         125  JUNIN      SAN GERÓNIMO                   CASACANCHA
# 126         126  JUNIN      SAN GERÓNIMO                    A.INGENIO
# 127         127  JUNIN      SAN GERÓNIMO      P.SANTA CRUZ DE QUILCAY
# 128         128  JUNIN      SAN GERÓNIMO                       RANGRA
# 161         161  JUNIN             TARMA                      P.TARMA
# 162         162  JUNIN             TARMA                         MACO
# 163         163  JUNIN             TARMA                     MULLUERO
# 164         164  JUNIN             TARMA                    ANDAMARCA
# 165         165  JUNIN             TARMA                      CHANCHA
# 166         166  JUNIN             TARMA                   TARMATAMBO
# 181         181  JUNIN             OROYA                      P.OROYA
# 182         182  JUNIN             OROYA                 HUAYNACANCHA
# 183         183  JUNIN             OROYA                        PACHA
# 184         184  JUNIN             OROYA                     HUAYHUAY
#
#      4_6_years_men  4_6_years_women  4_6_years_total  6_14_years_men  \
# 0               65               46              111             297
# 1                1                3                4              49
# 2                1                0                1              46
# 3                0                6                6              25
# 4                4                4                8              21
# 5                6                7               13              44
# 6                9                8               17              31
# 7               18               23               41              90
# 8                7                4               11              42
# 9               16                8               24              26
# 10               8                6               14              17
# 11               2                6                8              10
# 12              12               14               26              38
# 13               8                0                8              17
# 47              69               71              140             375
# 48              12               11               23              45
# 49               1                7                8              24
# 50               3                2                5              29
# 51              22               38               60             103
# 52               1                4                5              84
# 53              27               15               42             148
# 54              24               22               46              74
# 55               9                9               18              57
# 56              19               11               30             106
# 57              36               21               57              98
# 58              21               13               34              85
# 74              45               38               83             160
# 75              16               12               28              94
# 76              20               13               33              87
# 77               2                0                2              16
# 78               2                2                4              29
# 79              11                2               13              13
# 80               8                3               11              25
# 96              38               43               81             178
# 97              28               32               60              95
# 98               3                0                3              47
# 99               3                8               11              22
# 100             10                8               18              68
# 101             16               11               27              30
# 121             51               42               93             246
# 122             20               20               40              92
# 123             19               13               32              73
# 124             13               19               32              62
# 125             10                9               19              28
# 126             18                6               24              77
# 127             21               20               41             101
# 128              7                1                8              26
# 161            107              117              224             386
# 162             28               12               40              72
# 163             11               14               25             114
# 164              7                6               13              68
# 165             17               20               37             122
# 166              3                1                4              72
# 181             11                9               20              41
# 182              4                2                6              11
# 183              2                4                6               7
# 184             13                8               21              55
#
#      6_14_years_women  6_14_years_total  ...  whites  natives  mestizos  \
# 0                 171               468  ...       4      284       290
# 1                  47                96  ...       0      100         0
# 2                  25                71  ...       0       69         3
# 3                  19                44  ...       0       25        25
# 4                  21                42  ...       0       37        13
# 5                  43                87  ...       0       65        35
# 6                  39                70  ...       0       87         0
# 7                  77               167  ...       4      175        29
# 8                  19                61  ...       0       70         2
# 9                  25                51  ...       0       73         2
# 10                 19                36  ...       0       50         0
# 11                 12                22  ...       0       24         6
# 12                 32                70  ...       0       96         0
# 13                 25                42  ...       0       44         6
# 47                327               702  ...      63      117       662
# 48                 21                66  ...       0       89         0
# 49                 18                42  ...       0       50         0
# 50                 40                69  ...       0       74         0
# 51                 87               190  ...       0      195        55
# 52                 52               136  ...       6      141         0
# 53                139               287  ...       0      294        29
# 54                 68               142  ...       0      104        84
# 55                 28                85  ...       0       99         4
# 56                144               250  ...       0      178        72
# 57                 93               191  ...       0      240         8
# 58                 69               154  ...       0       65       123
# 74                117               277  ...       0      333        27
# 75                 55               149  ...       0      167        10
# 76                 52               139  ...       0      169         3
# 77                 22                38  ...       0       40         0
# 78                 21                50  ...       0       54         0
# 79                  4                17  ...       0       30         0
# 80                 10                35  ...       0       46         0
# 96                164               342  ...       0      141       282
# 97                 93               188  ...       0      183        65
# 98                 41                88  ...       0       90         1
# 99                 29                51  ...       0       62         0
# 100                46               114  ...       0      132         0
# 101                41                71  ...       0       98         0
# 121               238               484  ...     348      157        72
# 122                90               182  ...     222        0         0
# 123                57               130  ...      50       64        48
# 124                56               118  ...      59       26        65
# 125                27                55  ...      31       35         8
# 126                75               152  ...      57       72        47
# 127                84               185  ...      31       42       153
# 128                12                38  ...      13       33         0
# 161               427               813  ...     158      189       689
# 162                52               124  ...       0      164         0
# 163                73               187  ...       0      179        33
# 164                52               120  ...       0       91        42
# 165                77               199  ...       0      228         8
# 166                32               104  ...       0      108         0
# 181                35                76  ...      15       28        53
# 182                16                27  ...       0       33         0
# 183                 3                10  ...       0       16         0
# 184                33                88  ...       0      108         1
#
#      blacks  Total_Poblacion  mujeres_nwrite  mujeres_nread  hombres_nwrite  \
# 0         1              579            25.0           25.0            35.0
# 1         0              100            50.0           50.0            20.0
# 2         0               72            35.0           35.0            31.0
# 3         0               50            50.0           50.0             0.0
# 4         0               50            50.0           50.0            44.0
# 5         0              100            46.0           46.0            37.0
# 6         0               87            54.0           54.0            46.0
# 7         0              208            38.0           38.0            36.0
# 8         0               72            29.0           29.0            68.0
# 9         0               75            44.0           44.0            55.0
# 10        0               50            50.0           50.0            50.0
# 11        0               30            60.0           60.0            40.0
# 12        0               96            48.0           48.0            52.0
# 13        0               50            50.0           50.0            44.0
# 47        0              842            26.0           26.0            21.0
# 48        0               89            36.0           36.0            33.0
# 49        0               50            50.0           50.0            16.0
# 50        0               74            57.0           57.0            26.0
# 51        0              250            46.0           46.0            16.0
# 52        0              147            38.0           38.0             7.0
# 53        0              323            46.0           46.0            26.0
# 54        0              188            39.0           39.0            32.0
# 55        0              103            33.0           33.0            26.0
# 56        0              250            45.0           45.0            17.0
# 57        0              248            45.0           45.0            37.0
# 58        0              188            44.0           44.0            30.0
# 74        0              360            44.0           44.0            39.0
# 75        0              177            38.0           38.0            43.0
# 76        0              172            36.0           36.0            23.0
# 77        0               40            55.0           55.0            40.0
# 78        0               54            43.0           43.0            44.0
# 79        0               30            20.0           20.0            70.0
# 80        0               46            28.0           28.0            33.0
# 96        0              423            40.0           40.0            32.0
# 97        0              248            48.0           48.0            28.0
# 98        0               91            43.0           43.0            18.0
# 99        0               62            60.0           60.0            19.0
# 100       0              132            41.0           41.0            38.0
# 101       0               98            53.0           53.0            45.0
# 121       0              577            36.0           36.0            23.0
# 122       0              222            49.0           49.0            32.0
# 123       0              162            42.0           42.0            23.0
# 124       0              150            48.0           48.0            29.0
# 125       0               74            49.0           49.0            30.0
# 126       0              176            44.0           44.0            28.0
# 127       0              226            45.0           45.0            45.0
# 128       0               46            28.0           28.0            39.0
# 161       1             1037            31.0           31.0            23.0
# 162       0              164            39.0           39.0            39.0
# 163       0              212            41.0           41.0            47.0
# 164       0              133            38.0           38.0            26.0
# 165       0              236            41.0           41.0            47.0
# 166       0              108            31.0           31.0            43.0
# 181       0               96            20.0           20.0            34.0
# 182       0               33            55.0           55.0            45.0
# 183       0               16            44.0           44.0            56.0
# 184       0              109            31.0           31.0            19.0
#
#      hombres_nread  percent_nativos
# 0             35.0             49.0
# 1             20.0            100.0
# 2             31.0             96.0
# 3              0.0             50.0
# 4             44.0             74.0
# 5             37.0             65.0
# 6             46.0            100.0
# 7             36.0             84.0
# 8             68.0             97.0
# 9             55.0             97.0
# 10            50.0            100.0
# 11            40.0             80.0
# 12            52.0            100.0
# 13            44.0             88.0
# 47            21.0             14.0
# 48            33.0            100.0
# 49            16.0            100.0
# 50            26.0            100.0
# 51            16.0             78.0
# 52             7.0             96.0
# 53            26.0             91.0
# 54            32.0             55.0
# 55            26.0             96.0
# 56            17.0             71.0
# 57            37.0             97.0
# 58            30.0             35.0
# 74            39.0             92.0
# 75            43.0             94.0
# 76            23.0             98.0
# 77            40.0            100.0
# 78            44.0            100.0
# 79            70.0            100.0
# 80            33.0            100.0
# 96            32.0             33.0
# 97            28.0             74.0
# 98            18.0             99.0
# 99            19.0            100.0
# 100           38.0            100.0
# 101           45.0            100.0
# 121           23.0             27.0
# 122           32.0              0.0
# 123           23.0             40.0
# 124           29.0             17.0
# 125           30.0             47.0
# 126           28.0             41.0
# 127           45.0             19.0
# 128           39.0             72.0
# 161           23.0             18.0
# 162           39.0            100.0
# 163           47.0             84.0
# 164           26.0             68.0
# 165           47.0             97.0
# 166           43.0            100.0
# 181           34.0             29.0
# 182           45.0            100.0
# 183           56.0            100.0
# 184           19.0             99.0
#
# [57 rows x 45 columns]

# %%
#extraer información de filas que cumplan la condición: cantidad de niños (4-6 años) mayor a 50 y de (6-14 años) > 70
cities = districts[(districts['4_6_years_men'] > 50) & (districts['6_14_years_men'] > 70) ]


cities
# Out:
#      Unnamed: 0 Region          District           comunidad  4_6_years_men  \
# 0             0  JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 47           47  JUNIN             JAUJA             P.JAUJA             69
# 121         121  JUNIN      SAN GERÓNIMO      P.SAN GERÓNIMO             51
# 161         161  JUNIN             TARMA             P.TARMA            107
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 0                 46              111             297               171
# 47                71              140             375               327
# 121               42               93             246               238
# 161              117              224             386               427
#
#      6_14_years_total  ...  whites  natives  mestizos  blacks  \
# 0                 468  ...       4      284       290       1
# 47                702  ...      63      117       662       0
# 121               484  ...     348      157        72       0
# 161               813  ...     158      189       689       1
#
#      Total_Poblacion  mujeres_nwrite  mujeres_nread  hombres_nwrite  \
# 0                579            25.0           25.0            35.0
# 47               842            26.0           26.0            21.0
# 121              577            36.0           36.0            23.0
# 161             1037            31.0           31.0            23.0
#
#      hombres_nread  percent_nativos
# 0             35.0             49.0
# 47            21.0             14.0
# 121           23.0             27.0
# 161           23.0             18.0
#
# [4 rows x 45 columns]

# %%
# ordenar de manera ascendente según total de la población y cantidad de población nativa
base = cities.sort_values(["Total_Poblacion","natives"])
base
# Out:
#      Unnamed: 0 Region          District           comunidad  4_6_years_men  \
# 121         121  JUNIN      SAN GERÓNIMO      P.SAN GERÓNIMO             51
# 0             0  JUNIN  CIUDAD DEL CERRO  C.CIUDAD DEL CERRO             65
# 47           47  JUNIN             JAUJA             P.JAUJA             69
# 161         161  JUNIN             TARMA             P.TARMA            107
#
#      4_6_years_women  4_6_years_total  6_14_years_men  6_14_years_women  \
# 121               42               93             246               238
# 0                 46              111             297               171
# 47                71              140             375               327
# 161              117              224             386               427
#
#      6_14_years_total  ...  whites  natives  mestizos  blacks  \
# 121               484  ...     348      157        72       0
# 0                 468  ...       4      284       290       1
# 47                702  ...      63      117       662       0
# 161               813  ...     158      189       689       1
#
#      Total_Poblacion  mujeres_nwrite  mujeres_nread  hombres_nwrite  \
# 121              577            36.0           36.0            23.0
# 0                579            25.0           25.0            35.0
# 47               842            26.0           26.0            21.0
# 161             1037            31.0           31.0            23.0
#
#      hombres_nread  percent_nativos
# 121           23.0             27.0
# 0             35.0             49.0
# 47            21.0             14.0
# 161           23.0             18.0
#
# [4 rows x 45 columns]

# %%
new_base = base[["District","comunidad","mujeres_nwrite","mujeres_nread","hombres_nwrite","hombres_nread","percent_nativos"]]
new_base
# Out:
#              District           comunidad  mujeres_nwrite  mujeres_nread  \
# 121      SAN GERÓNIMO      P.SAN GERÓNIMO            36.0           36.0
# 0    CIUDAD DEL CERRO  C.CIUDAD DEL CERRO            25.0           25.0
# 47              JAUJA             P.JAUJA            26.0           26.0
# 161             TARMA             P.TARMA            31.0           31.0
#
#      hombres_nwrite  hombres_nread  percent_nativos
# 121            23.0           23.0             27.0
# 0              35.0           35.0             49.0
# 47             21.0           21.0             14.0
# 161            23.0           23.0             18.0

# %%
Base1 = new_base.iloc[0:2]
Base1
# Out:
#              District           comunidad  mujeres_nwrite  mujeres_nread  \
# 121      SAN GERÓNIMO      P.SAN GERÓNIMO            36.0           36.0
# 0    CIUDAD DEL CERRO  C.CIUDAD DEL CERRO            25.0           25.0
#
#      hombres_nwrite  hombres_nread  percent_nativos
# 121            23.0           23.0             27.0
# 0              35.0           35.0             49.0

# %%
Base2 = new_base.iloc[2:4]
Base2
# Out:
#     District comunidad  mujeres_nwrite  mujeres_nread  hombres_nwrite  \
# 47     JAUJA   P.JAUJA            26.0           26.0            21.0
# 161    TARMA   P.TARMA            31.0           31.0            23.0
#
#      hombres_nread  percent_nativos
# 47            21.0             14.0
# 161           23.0             18.0

# %%
Base1.to_csv("Base1_WG5.csv")

# %%
Base2.to_excel("Base2_WG5.xlsx")

# %% [markdown]
# #### 10. Crear una función que me permita extraer columnas un rango de columnas y de filas. Crear una función que me permite extraer una columna según el nombre de la variable y dos filas.

# %%
def funcion1(data_base, posición_fila1, posición_fila2, posición_columna1, posición_columna2):
    data_base.iloc[posición_fila1:posición_fila2,posición_columna1:posición_columna2]

# %%
def funcion2(base_datos,nombre_columna, posición_fila1, posición_fila2):
    base_datos[["nombre_columna"]].iloc[posición_fila1:posición_fila2]
