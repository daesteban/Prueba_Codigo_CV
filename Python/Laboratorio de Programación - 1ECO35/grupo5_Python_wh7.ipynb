# %% [markdown]
# # Grupo 5 - WH7 - Python
# ### Integrantes
# - Diego
# - Teresa
# - Yoberson

# %%
#Instalando librerias
# !pip install selenium
# !pip install webdriver-manager

# %%
# this library is to manipulate browser
from selenium import webdriver

# it allows you to work with differen versions of drivers
# We call ChromeDriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support.select import Select
import re
import time

# %%
import os
import sys

# %% [markdown]
# **Repositorio del curso**

# %%
driver = webdriver.Chrome( ChromeDriverManager().install() )

url = 'https://github.com/Robertopucp/1ECO35_R_PYTHON'
driver.get( url )

driver.maximize_window()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - There is no [win32] chromedriver for browser 102.0.5005 in cache
# [WDM] - About to download new driver from https://chromedriver.storage.googleapis.com/102.0.5005.61/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\Coms By Gigabyte\.wdm\drivers\chromedriver\win32\102.0.5005.61]
# C:\Users\COMSBY~1\AppData\Local\Temp/ipykernel_11068/1707408.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome( ChromeDriverManager().install() )

# %%
driver.execute_script("document.body.style.zoom='100%'")

# %%
driver.page_source
# Out:
# '<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system"><head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin="">\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-ksfTgQOOnE+FFXf+yNfVjKSlEckJAdufFIYGK7ZjRhWcZgzAGcmZqqArTgMLpu90FwthqcCX4ldDgKXbmVMeuQ==" rel="stylesheet" href="https://github.githubassets.com/assets/light-92c7d381038e.css"><link crossorigin="anonymous" media="all" integrity="sha512-1KkMNn8M/al/dtzBLupRwkIOgnA9MWkm8oxS+solP87jByEvY/g4BmoxLihRogKcX1obPnf4Yp7dI0ZTWO+ljg=
# ...

# %% [markdown]
# **Inflación anual**

# %%
driver1 = webdriver.Chrome( ChromeDriverManager().install() )

url = 'https://www.bcrp.gob.pe/docs/Publicaciones/Nota-Semanal/2020/resumen-informativo-2020-04-02/?utm_source=phplist4557&utm_medium=email&utm_content=HTML&utm_campaign=BCRP%3A+Resumen+Informativo+Semanal+-+2+de+abril+de+2020#viii-3'
driver1.get( url )

driver1.maximize_window()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [C:\Users\Esteban\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# C:\Users\Esteban\AppData\Local\Temp\ipykernel_26600\2786520800.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver1 = webdriver.Chrome( ChromeDriverManager().install() )

# %%
driver1.execute_script("document.body.style.zoom='100%'")

# %%
driver1.page_source
# Out:
# '<html><head></head><body><div>\n<table align="center" style="border: 1px solid rgb(187, 187, 187); width: 820px; height: auto; overflow: hidden; padding-bottom: 20px;">\n<tbody><tr>\n<td align="middle" colspan="2" style="background-color:#004293;"><img src="http://www.bcrp.gob.pe/images/stories/Correos/nota-semanal/2020/2020-04-02/resumen-informativo-cabecera.jpg" width="780" height="90"></td></tr>\n<tr>\n<td align="middle" valign="top">\n<table cellpadding="8" cellspacing="0" style="margin: 5px 15px; padding: 0px 10px; width: 480px; height: 70px;">\n<tbody><tr>\n<td>\n<table cellspacing="5px" style="font-family: Arial,Verdana,sans-serif;"> \n<tbody><tr>\n  <td valign="top">»</td>\n  <td colspan="2"><a href="#i" border="0">\n    <span style="font-size: 16px; text-decoration:none;">Inflación anual de marzo en el rango meta</span>\n    </a></td>\n</tr> \n<tr>\n  <td valign="top">»</td>\n  <td colspan="2"><a href="#ii" border="0">\n    <span style="font-size: 16px; text-decoration:none
# ...

# %%
elements = driver1.find_elements(By.TAG_NAME, 'img')
elements[2].click()
elements[2]
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="634ae04aa2b8c7457c6d808a5345433e", element="b316bc84-6b63-48b1-8e6c-fc0ce4144f0c")>

# %%
results = driver1.find_element_by_xpath('/html/body/div/table/tbody/tr/td/table/tbody/tr/td/p/img')
# Out:
# C:\Users\Esteban\AppData\Local\Temp\ipykernel_26600\4190550744.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   results = driver1.find_element_by_xpath('/html/body/div/table/tbody/tr/td/table/tbody/tr/td/p/img')

# %%
results
results.click()

# %% [markdown]
# INFLACIÓN ANUAL DE MARZO EN EL RANGO META
#
# |        | Total | Sin alimentos  y energía | Alimentos y  Energía | Tendencial |
# |:------:|:-----:|:------------------------:|:--------------------:|:----------:|
# | Dic.19 |  1,9  |            2,3           |          1,4         |     1,7    |
# | Ene.20 |  1,9  |            2,3           |          1,4         |     1,8    |
# | Feb.20 |  1,9  |            2,3           |          1,4         |     1,7    |
# | Mar.20 |  1,8  |            1,7           |          1,9         |     1,6    |

# %% [markdown]
# **Numero 3**
# Crear las siguientes opciones para marcar (Lima Metropolitana, Lima provincia y Lima región ). Crear una lista despegable con las opciones de 5 distritos de Lima.

# %%
from IPython.display import display, HTML

# %%
<html>
<body>

<h1>Lugar</h1>

<form action="/action_page.php">
  <input type="radio" id="limam" name="lugar" value="Lima Metropolitana">
  <label for="limam">Lima Metropolitana</label><br>
  <input type="radio" id="limap" name="lugar" value="Lima Provincia">
  <label for="limap">Lima Provincia</label><br>
  <input type="radio" id="limar" name="lugar" value="Lima Región">
      <label for="limar">Lima Región</label><br>     
    </form>
    
<h1>Seleccionar distrito</h1>
<form action="/action_page.php">
  <label for="distrito">Selecciona un distrito:</label>
  <select name="distrito" id="distrito">
    <option value="San Juan de Miraflores">San Juan de Miraflores</option>
    <option value="San Miguel">San Miguel</option>
    <option value="Chorillos">Chorillos</option>
    <option value="Magdalena del Mar">Magdalena del Mar</option>
    <option value="Pueblo Libre">Pueblo Libre</option>
  </select>
  <br><br>
</form>
    <button onclick="showContent()">Enviar</button>
    
</body>
</html>
# Out:
#   File "C:\Users\COMSBY~1\AppData\Local\Temp/ipykernel_11068/3828148665.py", line 1
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Numero 4**
# Crear un formulario para ingresar el nombre, apellidos, DNI y correo electrónico. Asimismo, debe añadirse un botón para enviar los resultados.

# %%
<!DOCTYPE html>
<html>
    <h1>FORMULARIO DE REGISTRO</h1>
<head>
<body>
<form action="/action_page.php">
  <label for="fname">Nombres:</label>
  <input type="text" id="fname" name="fname" placeholder="Ingrese su nombre"><br><br>
  <label for="lname">Apellidos:</label>
  <input type="text" id="lname" name="lname" placeholder="Ingrese sus apellidos"><br><br>
  <label for="lname">DNI:</label>
  <input type="text" id="DNI" name="DNI" placeholder="Ingrese su DNI"><br><br>
  <label for="lname">Email:</label>
  <input type="text" id="email" name="email" placeholder="Ingrese su email"><br><br>
  <button onclick="showContent()">Registrar</button>
</form>
</body>
<footer>
    <p>Estoy de acuerdo con <a href='#'>los términos y condiciones.</a></p>  
</footer>
</html>

# %% [markdown]
# **Pagina Onpe - Scrapper**

# %% [markdown]
# # Página Onpe - Scrapper
# Extraer información de votos congresales de las ultimas elecciones general link.
#
# Extraer la siguiente tabla por cada departamento (nombre de organización política, total, % votos validos, % votos emitidos. No considerar residentes en el extranjero. Debe concatenar las tablas en DataFrame y exportarlo en Excel con el siguiente nombre onpe_congreso_grupo_(numero de grupo).xls

# %%
#!pip install selenium
#!pip install webdriver-manager
#!pip install lxml
#!pip install lxmunidecodel
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement lxmunidecodel (from versions: none)
# ERROR: No matching distribution found for lxmunidecodel

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import ActionChains
import pandas as pd
import numpy as np
import os
import sys
import time
import re
import unidecode 
from selenium.webdriver.support.ui import Select

# %%
driver = webdriver.Chrome( ChromeDriverManager().install() )
driver.maximize_window()

driver.get( 'https://resultadoshistorico.onpe.gob.pe/EG2021/' )
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [C:\Users\teresa\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# <ipython-input-88-bc84ad8dbfb8>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome( ChromeDriverManager().install() )

# %%
congresal = driver.find_element_by_xpath('/html/body/onpe-root/onpe-home-onpe/div[1]/div/div/div/div[2]/div[3]/div/div/a/div[2]')
congresal.click()
# Out:
# <ipython-input-89-ce38594a3f92>:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   congresal = driver.find_element_by_xpath('/html/body/onpe-root/onpe-home-onpe/div[1]/div/div/div/div[2]/div[3]/div/div/a/div[2]')

# %%
all_tables = {}

# %%
for index in range(26):
    
    dpt = Select( driver.find_element_by_id( "select_departamento" ) )  
    departamento = dpt.options[ index ]
    
    dpt_name = departamento.text # nombre del departamento
    print(dpt_name)
    departamento.click()
    
    # tabla y html
    table_path = driver.find_element_by_id('table1')
    table_html = table_path.get_attribute('outerHTML')
    table = pd.read_html( table_html ) 
                                           
    all_tables[ ubigeo ] = table_clean
# Out:
# <ipython-input-97-3dad0b472e28>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dpt = Select( driver.find_element_by_id( "select_departamento" ) )
# AMAZONAS
# <ipython-input-97-3dad0b472e28>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   table_path = driver.find_element_by_id('table1')
# ANCASH
# APURIMAC
# AREQUIPA
# AYACUCHO
# CAJAMARCA
# CALLAO
# CUSCO
# HUANCAVELICA
# HUANUCO
# ICA
# JUNIN
# LA LIBERTAD
# LAMBAYEQUE
# LIMA
# LIMA PROVINCIAS
# LORETO
# MADRE DE DIOS
# MOQUEGUA
# PASCO
# PIURA
# PUNO
# SAN MARTIN
# TACNA
# TUMBES
# UCAYALI

# %%
votos = pd.concat( all_tables.values() ).reset_index( drop = True )
votos
# Out:
#                          organizaciones_políticas   total share_válidos  \
# 0   FRENTE POPULAR AGRICOLA FIA DEL PERU - FREPAP    9967        5.802%
# 1                    PARTIDO NACIONALISTA PERUANO    2644        1.539%
# 2                                  PARTIDO MORADO    3672        2.138%
# 3                               VICTORIA NACIONAL    9957        5.797%
# 4                                  ACCION POPULAR   20274       11.803%
# 5                                    PODEMOS PERU   15619        9.093%
# 6                              JUNTOS POR EL PERU   13665        7.955%
# 7                 PARTIDO POPULAR CRISTIANO - PPC    3808        2.217%
# 8                                  FUERZA POPULAR   30098       17.522%
# 9                               UNION POR EL PERU    8389        4.884%
# 10                             RENOVACION POPULAR    9623        5.602%
# 11                    RENACIMIENTO UNIDO NACIONAL    1112        0.647%
# ...

# %%
votos.to_excel( r'onpe_congreso_grupo_5.xlsx' , index = False )

# %%
driver.close()
